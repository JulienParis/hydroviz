# %%
''' 
STATIONS - PESTICIDES - STATS
-----------------------------

GOAL : notebook python functions to add at root (app initialization on run.py) 
create panda objects / implement query functions / export to JSON 
for data analysis and visualization

- READ .CSV AND .XLSX FILES (DATA) AND CONVERT IT TO PANDAS DATAFRAMES
- CHANGE COORD STATIONS TO WGS_84 (LAT/LONG)
- CLEAN AND MERGE DATA
- QUERY FUNCTIONS
- EXPORT FUNCTIONS (JSON)

AUTHOR : Julien Paris
DATE   : 24/12/2016

TO DO : 
- 
'''
# Out:
# ' \nSTATIONS - PESTICIDES - STATS\n-----------------------------\n\nGOAL : notebook python functions to add at root (app initialization on run.py) \ncreate panda objects / implement query functions / export to JSON \nfor data analysis and visualization\n\n- READ .CSV AND .XLSX FILES (DATA) AND CONVERT IT TO PANDAS DATAFRAMES\n- CHANGE COORD STATIONS TO WGS_84 (LAT/LONG)\n- CLEAN AND MERGE DATA\n- QUERY FUNCTIONS\n- EXPORT FUNCTIONS (JSON)\n\nAUTHOR : Julien Paris\nDATE   : 24/12/2016\n\nTO DO : \n- \n'

# %%
### import standard libraries
import os
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# pyproj settings to convert coordinates
from pyproj import Proj, transform
inProj  = Proj(init='epsg:2154') # proj in  : Lambert 93
outProj = Proj(init='epsg:4326') # proj out : WSG 84

# %%
### basic folders addresses and names
cwd = os.getcwd()
data_folder = "/data"
data_folder_ = "data/"


print "-- cwd :", cwd
for file in os.listdir(cwd + data_folder):
    if file.endswith(".csv") or file.endswith(".xlsx"):
        print "--- dataset in '/data' : ", file
        #print cwd+datas_folder+"/"+file
# Out:
# -- cwd : /Users/jpy/Dropbox/_FLASK/concours_pesticides/_jupyter_notebook
# --- dataset in '/data' :  ma_qp_fm_rcsrco_pesteso_2010.csv
# --- dataset in '/data' :  ma_qp_fm_rcsrco_pesteso_2011.csv
# --- dataset in '/data' :  ma_qp_fm_rcsrco_pesteso_2012.csv
# --- dataset in '/data' :  ma_qp_fm_ttres_pesteso_2007.csv
# --- dataset in '/data' :  ma_qp_fm_ttres_pesteso_2008.csv
# --- dataset in '/data' :  ma_qp_fm_ttres_pesteso_2009.csv
# --- dataset in '/data' :  moy_tot_quantif_2007.csv
# --- dataset in '/data' :  moy_tot_quantif_2008.csv
# --- dataset in '/data' :  moy_tot_quantif_2009.xlsx
# --- dataset in '/data' :  moy_tot_quantif_2010.csv
# --- dataset in '/data' :  moy_tot_quantif_2011.csv
# --- dataset in '/data' :  moy_tot_quantif_2012.csv
# --- dataset in '/data' :  pesticides.csv
# --- dataset in '/data' :  stations.csv

# %%
### panda dataframes for every db + settings

# set encoding of .csv (keep accents)
csv_encoding = "latin-1"

# set time frame
time_frame   = [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015 ]
#np.array = time_frame

# root strings for datas names
root_mct = "df_mct_"
root_ma  = "df_ma_"

# list of datas filenames
datas_stations   = "stations.csv"
datas_pesticides = "pesticides.csv"

datas_MCT = [
    "moy_tot_quantif_2007.csv",
    "moy_tot_quantif_2008.csv",
    "moy_tot_quantif_2009.xlsx", #### 
    "moy_tot_quantif_2010.csv",
    "moy_tot_quantif_2011.csv",
    "moy_tot_quantif_2012.csv",
]

datas_MA = [
    "ma_qp_fm_ttres_pesteso_2007.csv",
    "ma_qp_fm_ttres_pesteso_2008.csv",
    "ma_qp_fm_ttres_pesteso_2009.csv",
    "ma_qp_fm_rcsrco_pesteso_2010.csv",
    "ma_qp_fm_rcsrco_pesteso_2011.csv",
    "ma_qp_fm_rcsrco_pesteso_2012.csv",
]

### tests on few sets ...

# %%
### functions : cleaning operations on dataframes

def checkDTypes (df) :
    # check data type
    
    #for index in df.indices :
    #    print index

    for col in df.columns :
        #label = col.values
        dtype = df[col].dtype
        
        print "---- dtypes : ", col, "/", dtype

# %%
def comas2points(df, list_col_names="all_col"): 
    # convert all weird "," to "." and then to float values
    
    if list_col_names == "all_col" : 
        df.loc[:, :] = df.replace(to_replace=',', value='.', regex=True)
    else : 
        df.loc[:, list_col_names ] = df.loc[:,list_col_names].replace(to_replace=',', value='.', regex=True)
    return df


def ints2floats(df, list_col_names, to="float") :
    
    if to == "float":
        df.loc[:, list_col_names] = df.loc[:, list_col_names].astype(float)
    elif to == "int" :
        df.loc[:, list_col_names] = df.loc[:, list_col_names].astype(int)        
    return df

# %%
def dfCleanNa(df_list): 
    # clean from NaN values if entire row is NaN
    
    df_list_clean = []
    for df in df_list :
        df_cleaned_01 = df.dropna(how="all") # on empty rows
        df_cleaned_02 = df_cleaned_01.dropna( axis=1, how="all") # on empty columns
        df_list_clean.append(df_cleaned_02)
    
    return df_list_clean

# %%
### -- DATAS TO DATA FRAMES -- ####################################

# %%
### -- pesticides --

df_pesticides = pd.read_csv("data/pesticides.csv", sep=";", encoding=csv_encoding)
df_pesticides = comas2points(df_pesticides, ["NORME_DCE"])
df_pesticides = ints2floats (df_pesticides, ["NORME_DCE"])

# set index : CODE_PESTICIDE 
df_pesticides.set_index(["CD_PARAMETRE", "LB_PARAMETRE"], inplace=True)

checkDTypes(df_pesticides)

#print df_pesticides.loc[:,["CODE_CAS"]]

df_pesticides.head()
# Out:
# ---- dtypes :  NOM_PARAM2 / object
# ---- dtypes :  CODE_FAMILLE / object
# ---- dtypes :  CODE_FONCTION / object
# ---- dtypes :  STATUT / object
# ---- dtypes :  METABOLITE / object
# ---- dtypes :  PARENT / object
# ---- dtypes :  NOM_PARENT / object
# ---- dtypes :  CODE_CAS / object
# ---- dtypes :  DATE_NA_USAGE / object
# ---- dtypes :  FORMULEB / object
# ---- dtypes :  NORME_DCE / float64
#                                                        NOM_PARAM2  \
# CD_PARAMETRE LB_PARAMETRE
# 1197         Heptachlore                              Heptachlore
# 1748         Heptachlore époxyde cis      Heptachlore époxyde cis
# 1749         Heptachlore époxyde trans  Heptachlore époxyde trans
# 1103         Aldrine                                      Aldrine
# 1173         Dieldrine                                  Dieldrine
#
#                                          CODE_FAMILLE CODE_FONCTION STATUT  \
# CD_PARAMETRE LB_PARAMETRE
# 1197         Heptachlore                Organochlorés             I    PNA
# 1748         Heptachlore époxyde cis    Organochlorés             I    PNA
# 1749         Heptachlore époxyde trans  Organochlorés             I    PNA
# 1103         Aldrine                    Organochlorés             I    PNA
# 1173         Dieldrine                  Organochlorés             I    PNA
#
#                                        METABOLITE PARENT NOM_PARENT  \
# CD_PARAMETRE LB_PARAMETRE
# 1197         Heptachlore                      NaN    NaN        NaN
# 1748         Heptachlore époxyde cis          NaN    NaN        NaN
# 1749         Heptachlore époxyde trans        NaN    NaN        NaN
# 1103         Aldrine                          NaN    NaN        NaN
# 1173         Dieldrine                        NaN    NaN        NaN
#
#                                           CODE_CAS DATE_NA_USAGE   FORMULEB  \
# CD_PARAMETRE LB_PARAMETRE
# 1197         Heptachlore                   76-44-8           NaN   C10H5Cl7
# 1748         Heptachlore époxyde cis     1024-57-3           NaN        NaN
# 1749         Heptachlore époxyde trans  28044-83-9           NaN        NaN
# 1103         Aldrine                      309-00-2    10/04/1994   C12H8Cl6
# 1173         Dieldrine                     60-57-1    10/04/1994  C12H8Cl6O
#
#                                         NORME_DCE
# CD_PARAMETRE LB_PARAMETRE
# 1197         Heptachlore                     0.03
# 1748         Heptachlore époxyde cis         0.03
# 1749         Heptachlore époxyde trans       0.03
# 1103         Aldrine                         0.03
# 1173         Dieldrine                       0.03

# %%
### -- stations --
lab_stations = "INFOS"
df_stations  = pd.read_csv( "data/"+datas_stations, sep=";", encoding=csv_encoding , na_values=[""] )

# add columns CD_PARAMETRE, LB_PARAMETRE
#df_stations["CD_PARAMETRE"] = 99999
#df_stations["LB_PARAMETRE"] = "all pesticides"

# set indexes
df_stations.set_index( ["CD_STATION"], inplace=True) 
#df_stations.set_index(["CD_STATION", "CD_PARAMETRE", "LB_PARAMETRE"], inplace=True) 


# get columns labels
#col_labels_stations = list(df_stations.columns.values)
#print " -- col_labels :", df_stations[0:5]

# add multilevel hierarchy on columns
#df_stations.columns = pd.MultiIndex.from_product([lab_stations, col_labels_stations, "NO_DATE"])
#df_stations.columns = pd.MultiIndex.from_product([lab_stations, col_labels_stations])

to_float = ["ALTITUDE", "PROFONDEUR_MAXI_POINT", "X_FICT_L93", "Y_FICT_L93"]

df_stations = comas2points(df_stations, to_float)
df_stations = ints2floats (df_stations, to_float)

print "-- indices names :", df_stations.index.name


### add column for long lat in WSG84

def convertCoordinates(row):
    x1,y1 = row["X_FICT_L93"], row["Y_FICT_L93"]
    convertedCoord = transform(inProj,outProj, x1, y1)
    return list(convertedCoord)

def extractFromList(index):
    value = row[colName][index]
    print value
    return value

df_stations["COORD_WSG84"] = df_stations.apply(convertCoordinates,axis=1)
#df_stations["LAT_WSG84"]   = df_stations.apply(lambda row: extractFromList(row['COORD_WSG84'], 0), axis=1)
#df_stations["LONG_WSG84"]  = df_stations.apply(extractFromList(index=1),axis=1)

## cf : http://chrisalbon.com/python/pandas_expand_cells_containing_lists.html
# expand df.tags into its own dataframe
coord = df_stations['COORD_WSG84'].apply(pd.Series)
# rename each variable is tags
#coord = coord.rename(columns = lambda x : 'COORD_' + str(x))
coord.columns = ["LAT_WSG84","LONG_WSG84"] 
#print coord.head()
# join the tags dataframe back to the original dataframe
df_stations = pd.concat( [df_stations, coord], axis=1, join="outer" )

print coord.head()
print 

print df_stations["Unnamed: 26"].unique()
df_stations.drop('Unnamed: 26', axis=1, inplace=True)



checkDTypes(df_stations)
print "-- df_stations.shape : ", df_stations.shape



df_stations.head()
# Out:
# -- indices names : CD_STATION
#                 LAT_WSG84  LONG_WSG84
# CD_STATION
# 06521X0019/SCE   5.452862   46.270740
# 07015X0009/F     5.781881   45.793046
# 07015X0010/P     5.772809   45.785001
# 07011X0009/F     5.788505   45.844201
# 06991X0001/S     5.074473   45.836095
#
# [ nan]
# ---- dtypes :  NUM_COM / object
# ---- dtypes :  NOM_COM / object
# ---- dtypes :  NUM_DEP / object
# ---- dtypes :  codagence / object
# ---- dtypes :  ALTITUDE / float64
# ---- dtypes :  PROFONDEUR_MAXI_POINT / float64
# ---- dtypes :  Unité_coord_fictifs / object
# ---- dtypes :  X_FICT_L93 / float64
# ---- dtypes :  Y_FICT_L93 / float64
# ---- dtypes :  CD_ME_v2 / object
# ---- dtypes :  CD_ME_niv1_surf / object
# ---- dtypes :  reseau2009 / object
# ---- dtypes :  reseau2010 / object
# ---- dtypes :  reseau2011 / object
# ---- dtypes :  reseau2012 / object
# ---- dtypes :  reseau2013 / object
# ---- dtypes :  reseau2014 / object
# ---- dtypes :  fi_ma_2007 / object
# ---- dtypes :  fi_ma_2008 / object
# ---- dtypes :  fi_ma_2009 / object
# ---- dtypes :  fi_ma_2010 / object
# ---- dtypes :  fi_ma_2011 / object
# ---- dtypes :  fi_ma_2012 / object
# ---- dtypes :  fi_ma_2013 / object
# ---- dtypes :  fi_ma_2014 / object
# ---- dtypes :  COORD_WSG84 / object
# ---- dtypes :  LAT_WSG84 / float64
# ---- dtypes :  LONG_WSG84 / float64
# -- df_stations.shape :  (13039, 28)
#                NUM_COM            NOM_COM NUM_DEP codagence  ALTITUDE  \
# CD_STATION
# 06521X0019/SCE   01125        CORVEISSIAT      01    AERM&C     459.0
# 07015X0009/F     01133  CRESSIN-ROCHEFORT      01    AERM&C     229.0
# 07015X0010/P     01133  CRESSIN-ROCHEFORT      01    AERM&C     229.8
# 07011X0009/F     01138              CULOZ      01    AERM&C     236.0
# 06991X0001/S     01142            DAGNEUX      01    AERM&C     196.0
#
#                 PROFONDEUR_MAXI_POINT    Unité_coord_fictifs   X_FICT_L93  \
# CD_STATION
# 06521X0019/SCE                    NaN        01125_ _FRDG140  888869.8607
# 07015X0009/F                     15.2  01133_FRDG511_FRDG330  916062.9395
# 07015X0010/P                     16.0  01133_FRDG511_FRDG330  915390.0333
# 07011X0009/F                     17.0  01138_FRDG511_FRDG330  916376.6040
# 06991X0001/S                     22.0  01142_FRDG240_FRDG390  861009.2195
#
#                  Y_FICT_L93 CD_ME_v2    ...     fi_ma_2008 fi_ma_2009  \
# CD_STATION                              ...
# 06521X0019/SCE  6577473.549      NaN    ...            oui        oui
# 07015X0009/F    6525297.883    DG330    ...            NaN        NaN
# 07015X0010/P    6524380.237    DG330    ...            oui        NaN
# 07011X0009/F    6530993.354    DG330    ...            oui        oui
# 06991X0001/S    6528387.253    DG390    ...            NaN        NaN
#
#                fi_ma_2010 fi_ma_2011 fi_ma_2012 fi_ma_2013 fi_ma_2014  \
# CD_STATION
# 06521X0019/SCE        NaN        NaN        NaN        NaN        NaN
# 07015X0009/F          NaN        NaN        NaN        NaN        NaN
# 07015X0010/P          NaN        NaN        NaN        NaN        NaN
# 07011X0009/F          NaN        NaN        NaN        NaN        NaN
# 06991X0001/S          oui        oui        oui        oui        oui
#
#                                    COORD_WSG84 LAT_WSG84 LONG_WSG84
# CD_STATION
# 06521X0019/SCE   [5.4528616689, 46.2707399979]  5.452862  46.270740
# 07015X0009/F    [5.78188086715, 45.7930456698]  5.781881  45.793046
# 07015X0010/P    [5.77280939367, 45.7850005571]  5.772809  45.785001
# 07011X0009/F    [5.78850460832, 45.8442013565]  5.788505  45.844201
# 06991X0001/S    [5.07447262804, 45.8360949687]  5.074473  45.836095
#
# [5 rows x 28 columns]

# %%
### -- pesticides / MCT (moy concentrations totales)  --
lab_MCT = "MCT"

## read datas MCT

df_mct_2007 = pd.read_csv("data/"+datas_MCT[0], sep=";") #,  index_col=[1,0])
df_mct_2008 = pd.read_csv("data/"+datas_MCT[1], sep=";") #,  index_col=[1,0])
df_mct_2009 = pd.read_excel("data/"+datas_MCT[2], sep=";") #,index_col=[1,0])
df_mct_2010 = pd.read_csv("data/"+datas_MCT[3], sep=";") #,  index_col=[1,0])
df_mct_2011 = pd.read_csv("data/"+datas_MCT[4], sep=";") #,  index_col=[1,0])
df_mct_2012 = pd.read_csv("data/"+datas_MCT[5], sep=";") #,  index_col=[1,0])

# %%
#df_mct_2007.shape
print " -- df_mct_2007.index.names : ", df_mct_2007.index.names
print " -- df_mct_2007.columns     : ", df_mct_2007.columns

df_mct_2007.head()
# Out:
#  -- df_mct_2007.index.names :  [None]
#  -- df_mct_2007.columns     :  Index([u'ANNEE', u'CD_STATION', u'NBPREL', u'MOYPTOT', u'MAXPTOT',
#        u'MINMOLRECH', u'MAXMOLRECH', u'MINMOLQ', u'MAQMOLQ'],
#       dtype='object')
#    ANNEE     CD_STATION  NBPREL MOYPTOT MAXPTOT  MINMOLRECH  MAXMOLRECH  \
# 0   2007  00054X0169/F1       4       0       0          18          96
# 1   2007  00057X0245/F1       2       0       0          18          96
# 2   2007  00057X0248/F4       2    0,02    0,04          61          96
# 3   2007  00061X0118/F8       4  0,0125    0,02          18          96
# 4   2007  00066X0042/SO       2    0,28    0,35          19          19
#
#    MINMOLQ  MAQMOLQ
# 0        0        0
# 1        0        0
# 2        0        1
# 3        0        1
# 4        2        2

# %%
#df_mct_2008.head()

# %%
df_ = df_mct_2010.dropna(how="all")
df_.loc[:, ("ANNEE")] = df_.loc[:, ("ANNEE")].astype(int)
#df_.head()
# Out:
# /Users/jpy/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
### merge all MCT datas with multiIndex
# cf : http://pandas.pydata.org/pandas-docs/stable/merging.html#joining-multiple-dataframe-or-panel-objects
# cf : http://pandas.pydata.org/pandas-docs/stable/merging.html#joining-with-two-multi-indexes
# options/alternatives : .merge .join .concat .append

frames_mct = [df_mct_2007,df_mct_2008, df_mct_2009, df_mct_2010, df_mct_2011, df_mct_2012]

# clean from NaN values if entire row is NaN
frames_mct_cleaned = dfCleanNa(frames_mct)
    
df_MCT = pd.concat(frames_mct_cleaned)

# convert all year column data to integers
df_MCT = ints2floats(df_MCT, ["ANNEE"], to="int")

# convert all weird "," to "." and then to float values
df_MCT   = comas2points(df_MCT)
to_float = ['NBPREL', 'MOYPTOT', 'MAXPTOT', 'MINMOLRECH', 'MAXMOLRECH', 'MINMOLQ', 'MAQMOLQ']
df_MCT   = ints2floats(df_MCT, to_float)
#df_MCT.loc[:, ("NBPREL"):("MAQMOLQ")] = df_MCT.loc[:, ("NBPREL"):("MAQMOLQ")].astype(float)

# add column CD_PARAMETRE, LB_PARAMETRE
df_MCT["CD_PARAMETRE"] = 9999
df_MCT["LB_PARAMETRE"] = "all_pesticides"

# set index hierarchy
#df_MCT.set_index(["CD_STATION", "ANNEE"], inplace=True)
df_MCT.set_index(["CD_STATION", "ANNEE", "CD_PARAMETRE", "LB_PARAMETRE"], inplace=True)

print " -- df_MCT.index.names    : ", df_MCT.index.names
print " -- df_MCT.index.values   : ", df_MCT.index.values
print " -- df_MCT.columns.values : ", df_MCT.columns.values
print " -- df_MCT.columns        : ", df_MCT.columns

df_MCT.sort_index(inplace=True) 

checkDTypes(df_MCT)

df_MCT.head(20)
# Out:
#  -- df_MCT.index.names    :  [u'CD_STATION', u'ANNEE', u'CD_PARAMETRE', u'LB_PARAMETRE']
#  -- df_MCT.index.values   :  [('00054X0169/F1', 2007, 9999, 'all_pesticides')
#  ('00057X0245/F1', 2007, 9999, 'all_pesticides')
#  ('00057X0248/F4', 2007, 9999, 'all_pesticides') ...,
#  ('11056X0123/FIGA', 2012, 9999, 'all_pesticides')
#  ('11195X0147/FITTEL', 2012, 9999, 'all_pesticides')
#  ('11221X0134/TRAVO', 2012, 9999, 'all_pesticides')]
#  -- df_MCT.columns.values :  ['NBPREL' 'MOYPTOT' 'MAXPTOT' 'MINMOLRECH' 'MAXMOLRECH' 'MINMOLQ' 'MAQMOLQ']
#  -- df_MCT.columns        :  Index([u'NBPREL', u'MOYPTOT', u'MAXPTOT', u'MINMOLRECH', u'MAXMOLRECH',
#        u'MINMOLQ', u'MAQMOLQ'],
#       dtype='object')
# ---- dtypes :  NBPREL / float64
# ---- dtypes :  MOYPTOT / float64
# ---- dtypes :  MAXPTOT / float64
# ---- dtypes :  MINMOLRECH / float64
# ---- dtypes :  MAXMOLRECH / float64
# ---- dtypes :  MINMOLQ / float64
# ---- dtypes :  MAQMOLQ / float64
#                                                  NBPREL  MOYPTOT  MAXPTOT  \
# CD_STATION    ANNEE CD_PARAMETRE LB_PARAMETRE
# 00054X0169/F1 2007  9999         all_pesticides     4.0   0.0000     0.00
#               2012  9999         all_pesticides     1.0   0.0000     0.00
# 00057X0245/F1 2007  9999         all_pesticides     2.0   0.0000     0.00
#               2008  9999         all_pesticides     1.0   0.0200     0.02
#               2010  9999         all_pesticides     1.0   0.0000     0.00
#               2012  9999         all_pesticides     1.0   0.0000     0.00
# 00057X0248/F4 2007  9999         all_pesticides     2.0   0.0200     0.04
#               2008  9999         all_pesticides     1.0   0.0000     0.00
#               2009  9999         all_pesticides     1.0   0.0000     0.00
#               2010  9999         all_pesticides     1.0   0.0000     0.00
#               2012  9999         all_pesticides     1.0   0.0000     0.00
# 00061X0118/F8 2007  9999         all_pesticides     4.0   0.0125     0.02
#               2009  9999         all_pesticides     2.0   0.0250     0.04
#               2010  9999         all_pesticides     2.0   0.0450     0.06
#               2011  9999         all_pesticides     2.0   0.0150     0.03
#               2012  9999         all_pesticides     2.0   0.0100     0.02
# 00066X0042/SO 2007  9999         all_pesticides     2.0   0.2800     0.35
#               2008  9999         all_pesticides     2.0   0.2700     0.45
#               2009  9999         all_pesticides     2.0   0.2900     0.35
#               2010  9999         all_pesticides     2.0   0.2950     0.30
#
#                                                  MINMOLRECH  MAXMOLRECH  \
# CD_STATION    ANNEE CD_PARAMETRE LB_PARAMETRE
# 00054X0169/F1 2007  9999         all_pesticides        18.0        96.0
#               2012  9999         all_pesticides        64.0        64.0
# 00057X0245/F1 2007  9999         all_pesticides        18.0        96.0
#               2008  9999         all_pesticides        60.0        60.0
#               2010  9999         all_pesticides        63.0        63.0
#               2012  9999         all_pesticides        64.0        64.0
# 00057X0248/F4 2007  9999         all_pesticides        61.0        96.0
#               2008  9999         all_pesticides        60.0        60.0
#               2009  9999         all_pesticides        62.0        62.0
#               2010  9999         all_pesticides        63.0        63.0
#               2012  9999         all_pesticides        64.0        64.0
# 00061X0118/F8 2007  9999         all_pesticides        18.0        96.0
#               2009  9999         all_pesticides        62.0        63.0
#               2010  9999         all_pesticides        63.0        63.0
#               2011  9999         all_pesticides        63.0        64.0
#               2012  9999         all_pesticides        64.0        64.0
# 00066X0042/SO 2007  9999         all_pesticides        19.0        19.0
#               2008  9999         all_pesticides        31.0        31.0
#               2009  9999         all_pesticides        31.0        31.0
#               2010  9999         all_pesticides        31.0        31.0
#
#                                                  MINMOLQ  MAQMOLQ
# CD_STATION    ANNEE CD_PARAMETRE LB_PARAMETRE
# 00054X0169/F1 2007  9999         all_pesticides      0.0      0.0
#               2012  9999         all_pesticides      0.0      0.0
# 00057X0245/F1 2007  9999         all_pesticides      0.0      0.0
#               2008  9999         all_pesticides      1.0      1.0
#               2010  9999         all_pesticides      0.0      0.0
#               2012  9999         all_pesticides      0.0      0.0
# 00057X0248/F4 2007  9999         all_pesticides      0.0      1.0
#               2008  9999         all_pesticides      0.0      0.0
#               2009  9999         all_pesticides      0.0      0.0
#               2010  9999         all_pesticides      0.0      0.0
#               2012  9999         all_pesticides      0.0      0.0
# 00061X0118/F8 2007  9999         all_pesticides      0.0      1.0
#               2009  9999         all_pesticides      1.0      2.0
#               2010  9999         all_pesticides      2.0      2.0
#               2011  9999         all_pesticides      0.0      2.0
#               2012  9999         all_pesticides      0.0      1.0
# 00066X0042/SO 2007  9999         all_pesticides      2.0      2.0
#               2008  9999         all_pesticides      1.0      2.0
#               2009  9999         all_pesticides      2.0      2.0
#               2010  9999         all_pesticides      2.0      2.0

# %%
### -- pesticides / MA (moy analyses)  --
lab_MA = "MA"

def multilevel_MA (df, year):

    # set indexes : STATION and CODE_PESTICIDE
    #df.set_index(["CD_STATION", "CD_PARAMETRE", "LB_PARAMETRE"], inplace=True)
    #df.set_index(["CD_STATION"], inplace=True)

    # get columns labels for df_ma
    #col_labels_df_ma = list(df.columns.values)
    #print " -- col_labels :", col_labels_df_ma

    # add multilevel hierarchy on columns
    #df.columns = pd.MultiIndex.from_product([lab_MA, col_labels_df_ma, year])
    
    # convert all weird "," to "." and then to float values
    to_float = ["MA_MOY", "NORME_DCE"]
    df       = comas2points(df, to_float)
    df       = ints2floats (df, to_float)

    df["ANNEE"] = year
    
    return df

# %%
df_ma_2007 = pd.read_csv("data/"+datas_MA[0], sep=";", encoding = csv_encoding)
df_ma_2007 = multilevel_MA(df_ma_2007, 2007)
    
df_ma_2008 = pd.read_csv("data/"+datas_MA[1], sep=";", encoding = csv_encoding)
df_ma_2008 = multilevel_MA(df_ma_2008, 2008)

df_ma_2009 = pd.read_csv("data/"+datas_MA[2], sep=";", encoding = csv_encoding)
df_ma_2009 = multilevel_MA(df_ma_2009, 2009)

df_ma_2010 = pd.read_csv("data/"+datas_MA[3], sep=";", encoding = csv_encoding)
df_ma_2010 = multilevel_MA(df_ma_2010, 2010)

df_ma_2011 = pd.read_csv("data/"+datas_MA[4], sep=";", encoding = csv_encoding)
df_ma_2011 = multilevel_MA(df_ma_2011, 2011)

df_ma_2012 = pd.read_csv("data/"+datas_MA[5], sep=";", encoding = csv_encoding)
df_ma_2012 = multilevel_MA(df_ma_2012, 2012)

# %%
df_ma_2010.head()
# Out:
#       CD_STATION  CD_PARAMETRE  NBANASPERTS1  MA_MOY  NBQUANTIF  NORME_DCE  \
# 0  00057X0245/F1          1101             1  0.0100          0       0.10
# 1  00057X0245/F1          1103             1  0.0025          0       0.03
# 2  00057X0245/F1          1104             1  0.0100          0       0.10
# 3  00057X0245/F1          1105             1  0.0500          0       0.10
# 4  00057X0245/F1          1107             1  0.0100          0       0.10
#
#     LB_PARAMETRE  ANNEE
# 0      Alachlore   2010
# 1        Aldrine   2010
# 2       Amétryne   2010
# 3  Aminotriazole   2010
# 4       Atrazine   2010

# %%
#df_ma_2011.head()

# %%
#df_ma_2012.head()

# %%
### merge all MA datas 

frames_MA = [df_ma_2007, df_ma_2008, df_ma_2009, df_ma_2010, df_ma_2011, df_ma_2012]

# clean from NaN values if entire row is NaN
frames_MA_cleaned = dfCleanNa(frames_MA)

# concatenate datas MA
df_MA = pd.concat(frames_MA_cleaned)

# set index hierarchy
#df_MA.set_index(["CD_STATION"], inplace=True)
#df_MA.set_index(["CD_STATION", "ANNEE"], inplace=True)
df_MA.set_index(["CD_STATION", "ANNEE", "CD_PARAMETRE", "LB_PARAMETRE"], inplace=True)

#df_MA.sort_index(inplace=True) 
df_MA.sortlevel(inplace=True) 

print " -- df_MA.index.names    : ", df_MA.index.names
print " -- df_MA.index.values   : ", df_MA.index.values
print " -- df_MA.columns.values : ", df_MA.columns.values
print " -- df_MA.columns        : ", df_MA.columns

checkDTypes(df_MA)

df_MA #.head()
# Out:
#  -- df_MA.index.names    :  [u'CD_STATION', u'ANNEE', u'CD_PARAMETRE', u'LB_PARAMETRE']
#  -- df_MA.index.values   :  [(u'00053X0002/SO1', 2007, 1102, u'Aldicarbe')
#  (u'00053X0002/SO1', 2007, 1107, u'Atrazine')
#  (u'00053X0002/SO1', 2007, 1108, u'Atrazine d\xe9s\xe9thyl') ...,
#  (u'11282X0005/ARAGUI', 2007, 2924, u'Benfuracarbe')
#  (u'11282X0005/ARAGUI', 2007, 2951, u'Iprovalicarb')
#  (u'11282X0005/ARAGUI', 2007, 5475, u'Thiofanox sulfoxyde')]
#  -- df_MA.columns.values :  [u'NBANASPERTS1' u'MA_MOY' u'NBQUANTIF' u'NORME_DCE']
#  -- df_MA.columns        :  Index([u'NBANASPERTS1', u'MA_MOY', u'NBQUANTIF', u'NORME_DCE'], dtype='object')
# ---- dtypes :  NBANASPERTS1 / int64
# ---- dtypes :  MA_MOY / float64
# ---- dtypes :  NBQUANTIF / int64
# ---- dtypes :  NORME_DCE / float64
#                                                                     NBANASPERTS1  \
# CD_STATION        ANNEE CD_PARAMETRE LB_PARAMETRE
# 00053X0002/SO1    2007  1102         Aldicarbe                                 1
#                         1107         Atrazine                                  1
#                         1108         Atrazine déséthyl                         1
#                         1109         Atrazine déisopropyl                      1
#                         1136         Chlortoluron                              1
#                         1137         Cyanazine                                 1
#                         1177         Diuron                                    1
#                         1205         Ioxynil                                   1
#                         1208         Isoproturon                               1
#                         1209         Linuron                                   1
#                         1216         Méthabenzthiazuron                        1
#                         1221         Métolachlore                              1
#                         1253         Prochloraz                                1
#                         1263         Simazine                                  1
#                         1266         Terbuméton                                1
#                         1268         Terbuthylazine                            1
#                         1359         Cyprodinil                                1
#                         1414         Propyzamide                               1
#                         1515         Métobromuron                              1
#                         1670         Métazachlore                              1
#                         1673         Hexazinone                                1
#                         1832         2-hydroxy atrazine                        1
#                         2045         Terbuthylazine déséthyl                   1
# 00053X0004/F1     2007  1102         Aldicarbe                                 1
#                         1107         Atrazine                                  1
#                         1108         Atrazine déséthyl                         1
#                         1109         Atrazine déisopropyl                      1
#                         1136         Chlortoluron                              1
#                         1137         Cyanazine                                 1
#                         1177         Diuron                                    1
# ...                                                                          ...
# 11282X0005/ARAGUI 2007  1970         Acifluorfen                               1
#                         2008         Flurtamone                                1
#                         2009         Fipronil                                  1
#                         2011         2,6-dichlorobenzamide                     1
#                         2012         Amidosulfuron                             1
#                         2013         Anthraquinone                             1
#                         2014         Azaconazole                               1
#                         2017         Clomazone                                 1
#                         2022         Fludioxonil                               1
#                         2026         Lufénuron                                 1
#                         2027         Ofurace                                   1
#                         2028         Quinoxyfen                                1
#                         2045         Terbuthylazine déséthyl                   1
#                         2046         Hexachlorocyclohexane epsilon             1
#                         2056         Fluquinconazole                           1
#                         2057         Fénamidone                                1
#                         2070         Quizalofop éthyl                          1
#                         2075         Fomesafen                                 1
#                         2546         Dimét(h)achlore                           1
#                         2563         Iodosulfuron                              1
#                         2565         Flupyrsulfuron méthyle                    1
#                         2576         Pyraclostrobine                           1
#                         2664         Spiroxamine                               1
#                         2678         Trifloxystrobine                          1
#                         2737         Desmethylnorflurazon                      1
#                         2743         Fenhexamid                                1
#                         2847         Didemethylisoproturon                     1
#                         2924         Benfuracarbe                              1
#                         2951         Iprovalicarb                              1
#                         5475         Thiofanox sulfoxyde                       1
#
#                                                                     MA_MOY  \
# CD_STATION        ANNEE CD_PARAMETRE LB_PARAMETRE
# 00053X0002/SO1    2007  1102         Aldicarbe                       0.050
#                         1107         Atrazine                        0.010
#                         1108         Atrazine déséthyl               0.005
#                         1109         Atrazine déisopropyl            0.005
#                         1136         Chlortoluron                    0.010
#                         1137         Cyanazine                       0.010
#                         1177         Diuron                          0.010
#                         1205         Ioxynil                         0.025
#                         1208         Isoproturon                     0.010
#                         1209         Linuron                         0.010
#                         1216         Méthabenzthiazuron              0.010
#                         1221         Métolachlore                    0.025
#                         1253         Prochloraz                      0.025
#                         1263         Simazine                        0.010
#                         1266         Terbuméton                      0.010
#                         1268         Terbuthylazine                  0.010
#                         1359         Cyprodinil                      0.025
#                         1414         Propyzamide                     0.025
#                         1515         Métobromuron                    0.025
#                         1670         Métazachlore                    0.025
#                         1673         Hexazinone                      0.025
#                         1832         2-hydroxy atrazine              0.005
#                         2045         Terbuthylazine déséthyl         0.005
# 00053X0004/F1     2007  1102         Aldicarbe                       0.050
#                         1107         Atrazine                        0.010
#                         1108         Atrazine déséthyl               0.005
#                         1109         Atrazine déisopropyl            0.005
#                         1136         Chlortoluron                    0.010
#                         1137         Cyanazine                       0.010
#                         1177         Diuron                          0.010
# ...                                                                    ...
# 11282X0005/ARAGUI 2007  1970         Acifluorfen                     0.020
#                         2008         Flurtamone                      0.010
#                         2009         Fipronil                        0.005
#                         2011         2,6-dichlorobenzamide           0.010
#                         2012         Amidosulfuron                   0.050
#                         2013         Anthraquinone                   0.010
#                         2014         Azaconazole                     0.020
#                         2017         Clomazone                       0.020
#                         2022         Fludioxonil                     0.020
#                         2026         Lufénuron                       0.010
#                         2027         Ofurace                         0.005
#                         2028         Quinoxyfen                      0.005
#                         2045         Terbuthylazine déséthyl         0.010
#                         2046         Hexachlorocyclohexane epsilon   0.005
#                         2056         Fluquinconazole                 0.005
#                         2057         Fénamidone                      0.025
#                         2070         Quizalofop éthyl                0.010
#                         2075         Fomesafen                       0.010
#                         2546         Dimét(h)achlore                 0.025
#                         2563         Iodosulfuron                    0.035
#                         2565         Flupyrsulfuron méthyle          0.050
#                         2576         Pyraclostrobine                 0.020
#                         2664         Spiroxamine                     0.050
#                         2678         Trifloxystrobine                0.025
#                         2737         Desmethylnorflurazon            0.025
#                         2743         Fenhexamid                      0.025
#                         2847         Didemethylisoproturon           0.010
#                         2924         Benfuracarbe                    0.050
#                         2951         Iprovalicarb                    0.050
#                         5475         Thiofanox sulfoxyde             0.025
#
#                                                                     NBQUANTIF  \
# CD_STATION        ANNEE CD_PARAMETRE LB_PARAMETRE
# 00053X0002/SO1    2007  1102         Aldicarbe                              0
#                         1107         Atrazine                               0
#                         1108         Atrazine déséthyl                      0
#                         1109         Atrazine déisopropyl                   0
#                         1136         Chlortoluron                           0
#                         1137         Cyanazine                              0
#                         1177         Diuron                                 0
#                         1205         Ioxynil                                0
#                         1208         Isoproturon                            0
#                         1209         Linuron                                0
#                         1216         Méthabenzthiazuron                     0
#                         1221         Métolachlore                           0
#                         1253         Prochloraz                             0
#                         1263         Simazine                               0
#                         1266         Terbuméton                             0
#                         1268         Terbuthylazine                         0
#                         1359         Cyprodinil                             0
#                         1414         Propyzamide                            0
#                         1515         Métobromuron                           0
#                         1670         Métazachlore                           0
#                         1673         Hexazinone                             0
#                         1832         2-hydroxy atrazine                     0
#                         2045         Terbuthylazine déséthyl                0
# 00053X0004/F1     2007  1102         Aldicarbe                              0
#                         1107         Atrazine                               0
#                         1108         Atrazine déséthyl                      0
#                         1109         Atrazine déisopropyl                   0
#                         1136         Chlortoluron                           0
#                         1137         Cyanazine                              0
#                         1177         Diuron                                 0
# ...                                                                       ...
# 11282X0005/ARAGUI 2007  1970         Acifluorfen                            0
#                         2008         Flurtamone                             0
#                         2009         Fipronil                               0
#                         2011         2,6-dichlorobenzamide                  0
#                         2012         Amidosulfuron                          0
#                         2013         Anthraquinone                          0
#                         2014         Azaconazole                            0
#                         2017         Clomazone                              0
#                         2022         Fludioxonil                            0
#                         2026         Lufénuron                              0
#                         2027         Ofurace                                0
#                         2028         Quinoxyfen                             0
#                         2045         Terbuthylazine déséthyl                0
#                         2046         Hexachlorocyclohexane epsilon          0
#                         2056         Fluquinconazole                        0
#                         2057         Fénamidone                             0
#                         2070         Quizalofop éthyl                       0
#                         2075         Fomesafen                              0
#                         2546         Dimét(h)achlore                        0
#                         2563         Iodosulfuron                           0
#                         2565         Flupyrsulfuron méthyle                 0
#                         2576         Pyraclostrobine                        0
#                         2664         Spiroxamine                            0
#                         2678         Trifloxystrobine                       0
#                         2737         Desmethylnorflurazon                   0
#                         2743         Fenhexamid                             0
#                         2847         Didemethylisoproturon                  0
#                         2924         Benfuracarbe                           0
#                         2951         Iprovalicarb                           0
#                         5475         Thiofanox sulfoxyde                    0
#
#                                                                     NORME_DCE
# CD_STATION        ANNEE CD_PARAMETRE LB_PARAMETRE
# 00053X0002/SO1    2007  1102         Aldicarbe                            0.1
#                         1107         Atrazine                             0.1
#                         1108         Atrazine déséthyl                    0.1
#                         1109         Atrazine déisopropyl                 0.1
#                         1136         Chlortoluron                         0.1
#                         1137         Cyanazine                            0.1
#                         1177         Diuron                               0.1
#                         1205         Ioxynil                              0.1
#                         1208         Isoproturon                          0.1
#                         1209         Linuron                              0.1
#                         1216         Méthabenzthiazuron                   0.1
#                         1221         Métolachlore                         0.1
#                         1253         Prochloraz                           0.1
#                         1263         Simazine                             0.1
#                         1266         Terbuméton                           0.1
#                         1268         Terbuthylazine                       0.1
#                         1359         Cyprodinil                           0.1
#                         1414         Propyzamide                          0.1
#                         1515         Métobromuron                         0.1
#                         1670         Métazachlore                         0.1
#                         1673         Hexazinone                           0.1
#                         1832         2-hydroxy atrazine                   0.1
#                         2045         Terbuthylazine déséthyl              0.1
# 00053X0004/F1     2007  1102         Aldicarbe                            0.1
#                         1107         Atrazine                             0.1
#                         1108         Atrazine déséthyl                    0.1
#                         1109         Atrazine déisopropyl                 0.1
#                         1136         Chlortoluron                         0.1
#                         1137         Cyanazine                            0.1
#                         1177         Diuron                               0.1
# ...                                                                       ...
# 11282X0005/ARAGUI 2007  1970         Acifluorfen                          0.1
#                         2008         Flurtamone                           0.1
#                         2009         Fipronil                             0.1
#                         2011         2,6-dichlorobenzamide                0.1
#                         2012         Amidosulfuron                        0.1
#                         2013         Anthraquinone                        0.1
#                         2014         Azaconazole                          0.1
#                         2017         Clomazone                            0.1
#                         2022         Fludioxonil                          0.1
#                         2026         Lufénuron                            0.1
#                         2027         Ofurace                              0.1
#                         2028         Quinoxyfen                           0.1
#                         2045         Terbuthylazine déséthyl              0.1
#                         2046         Hexachlorocyclohexane epsilon        0.1
#                         2056         Fluquinconazole                      0.1
#                         2057         Fénamidone                           0.1
#                         2070         Quizalofop éthyl                     0.1
#                         2075         Fomesafen                            0.1
#                         2546         Dimét(h)achlore                      0.1
#                         2563         Iodosulfuron                         0.1
#                         2565         Flupyrsulfuron méthyle               0.1
#                         2576         Pyraclostrobine                      0.1
#                         2664         Spiroxamine                          0.1
#                         2678         Trifloxystrobine                     0.1
#                         2737         Desmethylnorflurazon                 0.1
#                         2743         Fenhexamid                           0.1
#                         2847         Didemethylisoproturon                0.1
#                         2924         Benfuracarbe                         0.1
#                         2951         Iprovalicarb                         0.1
#                         5475         Thiofanox sulfoxyde                  0.1
#
# [2779684 rows x 4 columns]

# %%
### --- tests .loc / queries

## cf : http://pandas.pydata.org/pandas-docs/stable/indexing.html#the-query-method-experimental

def queryByIndexValue (df, indexName, indexLabelList):
    queryString = '%s in %s' %( indexLabelList, indexName)
    #print queryString
    result = df.query(queryString)
    return result

def queryByColValue (df, colName, comparator, colValue ):
    queryString = '(%s %s %s)' %( colName, comparator, colValue)
    #print queryString
    result = df.query(queryString)
    return result


def getIndexValuesList(df, indexName):
    result = df.index.get_level_values(indexName).unique()
    return list(result)

def getColValuesList(df, colName ) :
    result = df[colName].unique()
    return list(result)


def listIndexUniqueValues(df) :
    dictIndex = {}
    for indexName in df.index.names :
        listValues = getIndexValuesList(df, indexName)
        dictIndex[indexName] = listValues
    return dictIndex

# %%
### tests queries 

df_sliced_01 = queryByIndexValue(df_stations, "CD_STATION", ["00066X0042/SO", "00053X0002/SO1"] )
df_sliced_02 = queryByIndexValue(df_stations, "NUM_DEP", ["44"] )
df_sliced_03 = queryByIndexValue(df_MCT, "ANNEE", [2009,2010] )
df_sliced_04 = queryByIndexValue(df_MA, "CD_STATION", ["00066X0042/SO", "00053X0002/SO1"] )

df_sliced_05 = queryByColValue(df_MA, "MA_MOY", ">", "NORME_DCE")

print "-- listIndexUniqueValues : ", listIndexUniqueValues(df_sliced_02)
print
print "-- getIndexValuesList : ", getIndexValuesList(df_sliced_04, "CD_PARAMETRE") 
print
print "-- getColValuesList : ", getColValuesList(df_MA, "NORME_DCE") 
print 
print "-- getColValuesList : ", getColValuesList(df_sliced_02, "NOM_COM")
# Out:
# -- listIndexUniqueValues :  {'CD_STATION': [u'05073X0019/S9', u'04818X0547/P44', u'04818X0574/F47', u'04818X0181/F2', u'04503X0014/F', u'04503X0009/FS9', u'04503X0013/FS14', u'04507X0006/FS15', u'04507X0051/F15B', u'04503X0079/F9BIS', u'04503X0067/PZ1', u'04503X0068/PZ2', u'04502X0045/SGB2', u'04807X0020/F', u'04807X0048/N17', u'04807X0018/P', u'04503X0048/FS6', u'04502X0032/F1', u'04502X0033/F2', u'04816X0400/F', u'05353X0015/F', u'05078X0003/P3', u'05078X0033/P7', u'04193X0025/PD2', u'04193X0020/P1-1', u'04494X0014/P', u'05092X0025/PS16', u'04514X0016/PB11', u'04514X0013/PB8', u'04514X0007/F2', u'04518X0066/P', u'04518X0037/NOR26', u'04518X0072/PB10BI', u'04514X0006/F1', u'04503X0047/FS5', u'04522X0014/S', u'04513X0007/F1', u'04513X0029/F2', u'04502X0039/F', u'04498X0018/F', u'04518X0045/MSM1', u'04191X0010/P', u'05086X0028/SEL3', u'04217X0003/F', u'04507X0043/SOURCE', u'05095X0042/P', u'04225X0014/F', u'04225X0050/P2']}
#
# -- getIndexValuesList :  [1102, 1107, 1108, 1109, 1136, 1137, 1177, 1205, 1208, 1209, 1216, 1221, 1253, 1263, 1266, 1268, 1359, 1414, 1515, 1670, 1673, 1832, 2045, 1105, 1203, 1506, 1907, 1954, 1092, 1125, 1133, 1184, 1189, 1215, 1234, 1473, 1688, 1744, 1911]
#
# -- getColValuesList :  [0.10000000000000001, 0.029999999999999999]
#
# -- getColValuesList :  [u'ARTHON-EN-RETZ', u'BASSE-GOULAINE', u'CAMPBON', u'DREFFEAC', u'FROSSAY', u'GUENROUET', u'INDRE', u'LEGE', u'MACHECOUL', u'MASSERAC', u'MISSILLAC', u'MOUZILLON', u'NORT-SUR-ERDRE', u'QUILLY', u'RIAILLE', u'SAFFRE', u'SAINT-GILDAS-DES-BOIS', u'SAINT-MALO-DE-GUERSAC', u'SAINT-MARS-DU-DESERT', u'SAINT-NICOLAS-DE-REDON', u'SAINT-PHILBERT-DE-GRAND-LIEU', u'SAINT-SULPICE-DES-LANDES', u'SAVENAY', u'VIEILLEVIGNE', u'VRITZ']

# %%
df_sliced_01
# Out:
#                NUM_COM   NOM_COM NUM_DEP codagence  ALTITUDE  \
# CD_STATION
# 00066X0042/SO    62228  CLERQUES      62      AEAP      55.0
# 00053X0002/SO1   62899   WISSANT      62      AEAP      20.0
#
#                 PROFONDEUR_MAXI_POINT Unité_coord_fictifs   X_FICT_L93  \
# CD_STATION
# 00066X0042/SO                     NaN     62228_ _FRAG001  629257.6535
# 00053X0002/SO1                    NaN     62899_ _FRAG001  607696.7319
#
#                  Y_FICT_L93 CD_ME_v2    ...     fi_ma_2008 fi_ma_2009  \
# CD_STATION                              ...
# 00066X0042/SO   7077908.332    AG001    ...            oui        oui
# 00053X0002/SO1  7090397.222      NaN    ...            NaN        NaN
#
#                fi_ma_2010 fi_ma_2011 fi_ma_2012 fi_ma_2013 fi_ma_2014  \
# CD_STATION
# 00066X0042/SO         oui        oui        NaN        oui        oui
# 00053X0002/SO1        NaN        NaN        NaN        NaN        NaN
#
#                                    COORD_WSG84 LAT_WSG84 LONG_WSG84
# CD_STATION
# 00066X0042/SO   [1.99856804486, 50.7936309591]  1.998568  50.793631
# 00053X0002/SO1  [1.69046823657, 50.9028310319]  1.690468  50.902831
#
# [2 rows x 28 columns]

# %%
df_sliced_02.head()
# Out:
#                NUM_COM         NOM_COM NUM_DEP codagence  ALTITUDE  \
# CD_STATION
# 05073X0019/S9    44005  ARTHON-EN-RETZ      44      AELB      9.00
# 04818X0547/P44   44009  BASSE-GOULAINE      44      AELB      3.34
# 04818X0574/F47   44009  BASSE-GOULAINE      44      AELB      4.00
# 04818X0181/F2    44009  BASSE-GOULAINE      44      AELB      5.00
# 04503X0014/F     44025         CAMPBON      44      AELB      6.00
#
#                 PROFONDEUR_MAXI_POINT    Unité_coord_fictifs   X_FICT_L93  \
# CD_STATION
# 05073X0019/S9                    13.4  44005_FRGG022_FRGG117  326378.1608
# 04818X0547/P44                   23.6  44009_FRGG022_FRGG114  362546.7259
# 04818X0574/F47                    NaN  44009_FRGG022_FRGG114  363236.6444
# 04818X0181/F2                    27.6  44009_FRGG022_FRGG114  361884.5177
# 04503X0014/F                     43.5  44025_FRGG022_FRGG038  325786.0052
#
#                  Y_FICT_L93 CD_ME_v2    ...     fi_ma_2008 fi_ma_2009  \
# CD_STATION                              ...
# 05073X0019/S9   6680644.213    GG117    ...            oui        NaN
# 04818X0547/P44  6690852.717    GG114    ...            oui        NaN
# 04818X0574/F47  6690653.620    GG114    ...            oui        NaN
# 04818X0181/F2   6690106.297    GG114    ...            oui        oui
# 04503X0014/F    6716500.751    GG038    ...            oui        oui
#
#                fi_ma_2010 fi_ma_2011 fi_ma_2012 fi_ma_2013 fi_ma_2014  \
# CD_STATION
# 05073X0019/S9         NaN        NaN        NaN        NaN        NaN
# 04818X0547/P44        NaN        NaN        NaN        NaN        NaN
# 04818X0574/F47        NaN        NaN        NaN        NaN        NaN
# 04818X0181/F2         oui        oui        oui        oui        oui
# 04503X0014/F          NaN        NaN        NaN        NaN        NaN
#
#                                     COORD_WSG84 LAT_WSG84 LONG_WSG84
# CD_STATION
# 05073X0019/S9   [-1.93119637304, 47.1210323175] -1.931196  47.121032
# 04818X0547/P44  [-1.46250512544, 47.2321328624] -1.462505  47.232133
# 04818X0574/F47  [-1.45325262097, 47.2306937831] -1.453253  47.230694
# 04818X0181/F2   [-1.47068526406, 47.2250868006] -1.470685  47.225087
# 04503X0014/F    [-1.96873154678, 47.4428611184] -1.968732  47.442861
#
# [5 rows x 28 columns]

# %%
df_sliced_03.head()
# Out:
#                                                  NBPREL  MOYPTOT  MAXPTOT  \
# CD_STATION    ANNEE CD_PARAMETRE LB_PARAMETRE
# 00057X0245/F1 2010  9999         all_pesticides     1.0    0.000     0.00
# 00057X0248/F4 2009  9999         all_pesticides     1.0    0.000     0.00
#               2010  9999         all_pesticides     1.0    0.000     0.00
# 00061X0118/F8 2009  9999         all_pesticides     2.0    0.025     0.04
#               2010  9999         all_pesticides     2.0    0.045     0.06
#
#                                                  MINMOLRECH  MAXMOLRECH  \
# CD_STATION    ANNEE CD_PARAMETRE LB_PARAMETRE
# 00057X0245/F1 2010  9999         all_pesticides        63.0        63.0
# 00057X0248/F4 2009  9999         all_pesticides        62.0        62.0
#               2010  9999         all_pesticides        63.0        63.0
# 00061X0118/F8 2009  9999         all_pesticides        62.0        63.0
#               2010  9999         all_pesticides        63.0        63.0
#
#                                                  MINMOLQ  MAQMOLQ
# CD_STATION    ANNEE CD_PARAMETRE LB_PARAMETRE
# 00057X0245/F1 2010  9999         all_pesticides      0.0      0.0
# 00057X0248/F4 2009  9999         all_pesticides      0.0      0.0
#               2010  9999         all_pesticides      0.0      0.0
# 00061X0118/F8 2009  9999         all_pesticides      1.0      2.0
#               2010  9999         all_pesticides      2.0      2.0

# %%
df_sliced_04
# Out:
#                                                                NBANASPERTS1  \
# CD_STATION     ANNEE CD_PARAMETRE LB_PARAMETRE
# 00053X0002/SO1 2007  1102         Aldicarbe                               1
#                      1107         Atrazine                                1
#                      1108         Atrazine déséthyl                       1
#                      1109         Atrazine déisopropyl                    1
#                      1136         Chlortoluron                            1
#                      1137         Cyanazine                               1
#                      1177         Diuron                                  1
#                      1205         Ioxynil                                 1
#                      1208         Isoproturon                             1
#                      1209         Linuron                                 1
#                      1216         Méthabenzthiazuron                      1
#                      1221         Métolachlore                            1
#                      1253         Prochloraz                              1
#                      1263         Simazine                                1
#                      1266         Terbuméton                              1
#                      1268         Terbuthylazine                          1
#                      1359         Cyprodinil                              1
#                      1414         Propyzamide                             1
#                      1515         Métobromuron                            1
#                      1670         Métazachlore                            1
#                      1673         Hexazinone                              1
#                      1832         2-hydroxy atrazine                      1
#                      2045         Terbuthylazine déséthyl                 1
# 00066X0042/SO  2007  1105         Aminotriazole                           2
#                      1107         Atrazine                                2
#                      1108         Atrazine déséthyl                       2
#                      1109         Atrazine déisopropyl                    2
#                      1137         Cyanazine                               2
#                      1177         Diuron                                  2
#                      1203         Hexachlorocyclohexane gamma             2
# ...                                                                     ...
#                2010  1954         Hydroxyterbuthylazine                   2
#                      2045         Terbuthylazine déséthyl                 2
#                2011  1092         Prosulfocarbe                           2
#                      1105         Aminotriazole                           2
#                      1107         Atrazine                                2
#                      1108         Atrazine déséthyl                       2
#                      1109         Atrazine déisopropyl                    2
#                      1133         Chloridazone                            2
#                      1177         Diuron                                  2
#                      1184         Ethofumésate                            2
#                      1189         Fenpropimorphe                          2
#                      1203         Hexachlorocyclohexane gamma             2
#                      1208         Isoproturon                             2
#                      1209         Linuron                                 2
#                      1215         Métamitrone                             2
#                      1221         Métolachlore                            2
#                      1234         Pendiméthaline                          2
#                      1263         Simazine                                2
#                      1266         Terbuméton                              2
#                      1268         Terbuthylazine                          2
#                      1359         Cyprodinil                              2
#                      1506         Glyphosate                              2
#                      1670         Métazachlore                            2
#                      1688         Aclonifène                              2
#                      1744         Epoxiconazole                           2
#                      1832         2-hydroxy atrazine                      2
#                      1907         AMPA                                    2
#                      1911         Imazaméthabenz-méthyl                   2
#                      1954         Hydroxyterbuthylazine                   2
#                      2045         Terbuthylazine déséthyl                 2
#
#                                                                MA_MOY  \
# CD_STATION     ANNEE CD_PARAMETRE LB_PARAMETRE
# 00053X0002/SO1 2007  1102         Aldicarbe                    0.0500
#                      1107         Atrazine                     0.0100
#                      1108         Atrazine déséthyl            0.0050
#                      1109         Atrazine déisopropyl         0.0050
#                      1136         Chlortoluron                 0.0100
#                      1137         Cyanazine                    0.0100
#                      1177         Diuron                       0.0100
#                      1205         Ioxynil                      0.0250
#                      1208         Isoproturon                  0.0100
#                      1209         Linuron                      0.0100
#                      1216         Méthabenzthiazuron           0.0100
#                      1221         Métolachlore                 0.0250
#                      1253         Prochloraz                   0.0250
#                      1263         Simazine                     0.0100
#                      1266         Terbuméton                   0.0100
#                      1268         Terbuthylazine               0.0100
#                      1359         Cyprodinil                   0.0250
#                      1414         Propyzamide                  0.0250
#                      1515         Métobromuron                 0.0250
#                      1670         Métazachlore                 0.0250
#                      1673         Hexazinone                   0.0250
#                      1832         2-hydroxy atrazine           0.0050
#                      2045         Terbuthylazine déséthyl      0.0050
# 00066X0042/SO  2007  1105         Aminotriazole                0.0500
#                      1107         Atrazine                     0.0900
#                      1108         Atrazine déséthyl            0.1900
#                      1109         Atrazine déisopropyl         0.0050
#                      1137         Cyanazine                    0.0100
#                      1177         Diuron                       0.0100
#                      1203         Hexachlorocyclohexane gamma  0.0025
# ...                                                               ...
#                2010  1954         Hydroxyterbuthylazine        0.0050
#                      2045         Terbuthylazine déséthyl      0.0050
#                2011  1092         Prosulfocarbe                0.0100
#                      1105         Aminotriazole                0.0500
#                      1107         Atrazine                     0.0650
#                      1108         Atrazine déséthyl            0.2000
#                      1109         Atrazine déisopropyl         0.0050
#                      1133         Chloridazone                 0.0100
#                      1177         Diuron                       0.0100
#                      1184         Ethofumésate                 0.0250
#                      1189         Fenpropimorphe               0.0100
#                      1203         Hexachlorocyclohexane gamma  0.0025
#                      1208         Isoproturon                  0.0100
#                      1209         Linuron                      0.0100
#                      1215         Métamitrone                  0.0100
#                      1221         Métolachlore                 0.0100
#                      1234         Pendiméthaline               0.0250
#                      1263         Simazine                     0.0100
#                      1266         Terbuméton                   0.0100
#                      1268         Terbuthylazine               0.0100
#                      1359         Cyprodinil                   0.0100
#                      1506         Glyphosate                   0.0500
#                      1670         Métazachlore                 0.0100
#                      1688         Aclonifène                   0.0250
#                      1744         Epoxiconazole                0.0100
#                      1832         2-hydroxy atrazine           0.0050
#                      1907         AMPA                         0.0500
#                      1911         Imazaméthabenz-méthyl        0.0100
#                      1954         Hydroxyterbuthylazine        0.0050
#                      2045         Terbuthylazine déséthyl      0.0050
#
#                                                                NBQUANTIF  \
# CD_STATION     ANNEE CD_PARAMETRE LB_PARAMETRE
# 00053X0002/SO1 2007  1102         Aldicarbe                            0
#                      1107         Atrazine                             0
#                      1108         Atrazine déséthyl                    0
#                      1109         Atrazine déisopropyl                 0
#                      1136         Chlortoluron                         0
#                      1137         Cyanazine                            0
#                      1177         Diuron                               0
#                      1205         Ioxynil                              0
#                      1208         Isoproturon                          0
#                      1209         Linuron                              0
#                      1216         Méthabenzthiazuron                   0
#                      1221         Métolachlore                         0
#                      1253         Prochloraz                           0
#                      1263         Simazine                             0
#                      1266         Terbuméton                           0
#                      1268         Terbuthylazine                       0
#                      1359         Cyprodinil                           0
#                      1414         Propyzamide                          0
#                      1515         Métobromuron                         0
#                      1670         Métazachlore                         0
#                      1673         Hexazinone                           0
#                      1832         2-hydroxy atrazine                   0
#                      2045         Terbuthylazine déséthyl              0
# 00066X0042/SO  2007  1105         Aminotriazole                        0
#                      1107         Atrazine                             2
#                      1108         Atrazine déséthyl                    2
#                      1109         Atrazine déisopropyl                 0
#                      1137         Cyanazine                            0
#                      1177         Diuron                               0
#                      1203         Hexachlorocyclohexane gamma          0
# ...                                                                  ...
#                2010  1954         Hydroxyterbuthylazine                0
#                      2045         Terbuthylazine déséthyl              0
#                2011  1092         Prosulfocarbe                        0
#                      1105         Aminotriazole                        0
#                      1107         Atrazine                             2
#                      1108         Atrazine déséthyl                    2
#                      1109         Atrazine déisopropyl                 0
#                      1133         Chloridazone                         0
#                      1177         Diuron                               0
#                      1184         Ethofumésate                         0
#                      1189         Fenpropimorphe                       0
#                      1203         Hexachlorocyclohexane gamma          0
#                      1208         Isoproturon                          0
#                      1209         Linuron                              0
#                      1215         Métamitrone                          0
#                      1221         Métolachlore                         0
#                      1234         Pendiméthaline                       0
#                      1263         Simazine                             0
#                      1266         Terbuméton                           0
#                      1268         Terbuthylazine                       0
#                      1359         Cyprodinil                           0
#                      1506         Glyphosate                           0
#                      1670         Métazachlore                         0
#                      1688         Aclonifène                           0
#                      1744         Epoxiconazole                        0
#                      1832         2-hydroxy atrazine                   0
#                      1907         AMPA                                 0
#                      1911         Imazaméthabenz-méthyl                0
#                      1954         Hydroxyterbuthylazine                0
#                      2045         Terbuthylazine déséthyl              0
#
#                                                                NORME_DCE
# CD_STATION     ANNEE CD_PARAMETRE LB_PARAMETRE
# 00053X0002/SO1 2007  1102         Aldicarbe                          0.1
#                      1107         Atrazine                           0.1
#                      1108         Atrazine déséthyl                  0.1
#                      1109         Atrazine déisopropyl               0.1
#                      1136         Chlortoluron                       0.1
#                      1137         Cyanazine                          0.1
#                      1177         Diuron                             0.1
#                      1205         Ioxynil                            0.1
#                      1208         Isoproturon                        0.1
#                      1209         Linuron                            0.1
#                      1216         Méthabenzthiazuron                 0.1
#                      1221         Métolachlore                       0.1
#                      1253         Prochloraz                         0.1
#                      1263         Simazine                           0.1
#                      1266         Terbuméton                         0.1
#                      1268         Terbuthylazine                     0.1
#                      1359         Cyprodinil                         0.1
#                      1414         Propyzamide                        0.1
#                      1515         Métobromuron                       0.1
#                      1670         Métazachlore                       0.1
#                      1673         Hexazinone                         0.1
#                      1832         2-hydroxy atrazine                 0.1
#                      2045         Terbuthylazine déséthyl            0.1
# 00066X0042/SO  2007  1105         Aminotriazole                      0.1
#                      1107         Atrazine                           0.1
#                      1108         Atrazine déséthyl                  0.1
#                      1109         Atrazine déisopropyl               0.1
#                      1137         Cyanazine                          0.1
#                      1177         Diuron                             0.1
#                      1203         Hexachlorocyclohexane gamma        0.1
# ...                                                                  ...
#                2010  1954         Hydroxyterbuthylazine              0.1
#                      2045         Terbuthylazine déséthyl            0.1
#                2011  1092         Prosulfocarbe                      0.1
#                      1105         Aminotriazole                      0.1
#                      1107         Atrazine                           0.1
#                      1108         Atrazine déséthyl                  0.1
#                      1109         Atrazine déisopropyl               0.1
#                      1133         Chloridazone                       0.1
#                      1177         Diuron                             0.1
#                      1184         Ethofumésate                       0.1
#                      1189         Fenpropimorphe                     0.1
#                      1203         Hexachlorocyclohexane gamma        0.1
#                      1208         Isoproturon                        0.1
#                      1209         Linuron                            0.1
#                      1215         Métamitrone                        0.1
#                      1221         Métolachlore                       0.1
#                      1234         Pendiméthaline                     0.1
#                      1263         Simazine                           0.1
#                      1266         Terbuméton                         0.1
#                      1268         Terbuthylazine                     0.1
#                      1359         Cyprodinil                         0.1
#                      1506         Glyphosate                         0.1
#                      1670         Métazachlore                       0.1
#                      1688         Aclonifène                         0.1
#                      1744         Epoxiconazole                      0.1
#                      1832         2-hydroxy atrazine                 0.1
#                      1907         AMPA                               0.1
#                      1911         Imazaméthabenz-méthyl              0.1
#                      1954         Hydroxyterbuthylazine              0.1
#                      2045         Terbuthylazine déséthyl            0.1
#
# [161 rows x 4 columns]

# %%
df_sliced_05
# Out:
#                                                                     NBANASPERTS1  \
# CD_STATION        ANNEE CD_PARAMETRE LB_PARAMETRE
# 00061X0120/F10    2009  1113         Bentazone                                 1
# 00066X0042/SO     2007  1108         Atrazine déséthyl                         2
#                   2008  1108         Atrazine déséthyl                         2
#                   2009  1108         Atrazine déséthyl                         2
#                   2010  1108         Atrazine déséthyl                         2
#                   2011  1108         Atrazine déséthyl                         2
# 00075X0158/F15    2008  1506         Glyphosate                                2
#                   2009  1506         Glyphosate                                2
# 00108X0004/GC1    2007  1108         Atrazine déséthyl                         1
#                   2008  1108         Atrazine déséthyl                         1
#                   2009  1108         Atrazine déséthyl                         1
# 00108X0005/GC1    2007  1108         Atrazine déséthyl                         4
#                   2009  1108         Atrazine déséthyl                         2
# 00111X0244/GC1    2007  1108         Atrazine déséthyl                         2
#                   2009  1108         Atrazine déséthyl                         1
# 00113X0115/P2     2012  1108         Atrazine déséthyl                         1
# 00115X0004/P1     2007  1108         Atrazine déséthyl                         1
#                   2008  1108         Atrazine déséthyl                         1
# 00115X0030/P1     2007  1108         Atrazine déséthyl                        13
#                   2008  1108         Atrazine déséthyl                         7
#                   2009  1108         Atrazine déséthyl                         2
#                   2010  1108         Atrazine déséthyl                         2
#                   2011  1108         Atrazine déséthyl                         2
# 00116X0001/P1     2007  1108         Atrazine déséthyl                         4
#                   2008  1108         Atrazine déséthyl                         2
#                   2009  1108         Atrazine déséthyl                         1
#                   2011  1108         Atrazine déséthyl                         2
# 00126X0128/SO     2009  1105         Aminotriazole                             2
#                         1506         Glyphosate                                2
#                         1907         AMPA                                      2
# ...                                                                          ...
# 10744X0001/F      2009  1113         Bentazone                                 1
# 10747X0035/HY     2007  1129         Carbendazime                              1
# 10783X0006/FREDE  2009  1954         Hydroxyterbuthylazine                     1
# 10795X0001/S      2008  1830         Déisopropyl-déséthyl-atrazine             3
#                   2009  1830         Déisopropyl-déséthyl-atrazine             4
# 10883X0210/FAGE   2007  1177         Diuron                                    1
# 10902X0002/S      2008  1830         Déisopropyl-déséthyl-atrazine             3
#                   2009  1830         Déisopropyl-déséthyl-atrazine             3
#                   2010  1830         Déisopropyl-déséthyl-atrazine             4
#                   2012  1830         Déisopropyl-déséthyl-atrazine             4
# 10903X0026/PENE   2008  1830         Déisopropyl-déséthyl-atrazine             3
#                   2009  1830         Déisopropyl-déséthyl-atrazine             4
#                   2010  1830         Déisopropyl-déséthyl-atrazine             4
#                   2011  1830         Déisopropyl-déséthyl-atrazine             4
#                   2012  1830         Déisopropyl-déséthyl-atrazine             4
# 10905X0014/D      2007  1506         Glyphosate                                1
#                   2008  1831         Simazine-hydroxy                          1
# 10907X0070/F      2007  1109         Atrazine déisopropyl                      1
#                         2045         Terbuthylazine déséthyl                   1
#                   2009  1831         Simazine-hydroxy                          1
#                         1954         Hydroxyterbuthylazine                     1
# 10915X0171/F      2011  1212         2,4-MCPA                                  5
# 10915X0315/F4     2007  1109         Atrazine déisopropyl                      1
# 10961X0030/GRABAS 2011  1529         Bitertanol                                4
#                         1694         Tébuconazole                              4
#                         1762         Penconazole                               4
#                         1906         Fenbuconazole                             4
# 10971X0058/F2     2009  2011         2,6-dichlorobenzamide                     1
# 10971X0200/MACHER 2008  1907         AMPA                                      4
# 11013X0002/F      2007  1263         Simazine                                  6
#
#                                                                       MA_MOY  \
# CD_STATION        ANNEE CD_PARAMETRE LB_PARAMETRE
# 00061X0120/F10    2009  1113         Bentazone                      0.220000
# 00066X0042/SO     2007  1108         Atrazine déséthyl              0.190000
#                   2008  1108         Atrazine déséthyl              0.200000
#                   2009  1108         Atrazine déséthyl              0.215000
#                   2010  1108         Atrazine déséthyl              0.220000
#                   2011  1108         Atrazine déséthyl              0.200000
# 00075X0158/F15    2008  1506         Glyphosate                     0.175000
#                   2009  1506         Glyphosate                     0.125000
# 00108X0004/GC1    2007  1108         Atrazine déséthyl              0.140000
#                   2008  1108         Atrazine déséthyl              0.180000
#                   2009  1108         Atrazine déséthyl              0.190000
# 00108X0005/GC1    2007  1108         Atrazine déséthyl              0.112500
#                   2009  1108         Atrazine déséthyl              0.120000
# 00111X0244/GC1    2007  1108         Atrazine déséthyl              0.105000
#                   2009  1108         Atrazine déséthyl              0.140000
# 00113X0115/P2     2012  1108         Atrazine déséthyl              0.140000
# 00115X0004/P1     2007  1108         Atrazine déséthyl              0.150000
#                   2008  1108         Atrazine déséthyl              0.110000
# 00115X0030/P1     2007  1108         Atrazine déséthyl              0.183846
#                   2008  1108         Atrazine déséthyl              0.191429
#                   2009  1108         Atrazine déséthyl              0.210000
#                   2010  1108         Atrazine déséthyl              0.110000
#                   2011  1108         Atrazine déséthyl              0.200000
# 00116X0001/P1     2007  1108         Atrazine déséthyl              0.120000
#                   2008  1108         Atrazine déséthyl              0.105000
#                   2009  1108         Atrazine déséthyl              0.110000
#                   2011  1108         Atrazine déséthyl              0.105000
# 00126X0128/SO     2009  1105         Aminotriazole                  0.525000
#                         1506         Glyphosate                     0.175000
#                         1907         AMPA                           0.325000
# ...                                                                      ...
# 10744X0001/F      2009  1113         Bentazone                      0.180000
# 10747X0035/HY     2007  1129         Carbendazime                   0.740000
# 10783X0006/FREDE  2009  1954         Hydroxyterbuthylazine          0.140000
# 10795X0001/S      2008  1830         Déisopropyl-déséthyl-atrazine  0.156667
#                   2009  1830         Déisopropyl-déséthyl-atrazine  0.135000
# 10883X0210/FAGE   2007  1177         Diuron                         0.120000
# 10902X0002/S      2008  1830         Déisopropyl-déséthyl-atrazine  0.240000
#                   2009  1830         Déisopropyl-déséthyl-atrazine  0.136667
#                   2010  1830         Déisopropyl-déséthyl-atrazine  0.200000
#                   2012  1830         Déisopropyl-déséthyl-atrazine  0.170000
# 10903X0026/PENE   2008  1830         Déisopropyl-déséthyl-atrazine  0.213333
#                   2009  1830         Déisopropyl-déséthyl-atrazine  0.175000
#                   2010  1830         Déisopropyl-déséthyl-atrazine  0.205000
#                   2011  1830         Déisopropyl-déséthyl-atrazine  0.177500
#                   2012  1830         Déisopropyl-déséthyl-atrazine  0.162500
# 10905X0014/D      2007  1506         Glyphosate                     0.104000
#                   2008  1831         Simazine-hydroxy               0.220000
# 10907X0070/F      2007  1109         Atrazine déisopropyl           0.120000
#                         2045         Terbuthylazine déséthyl        0.200000
#                   2009  1831         Simazine-hydroxy               0.410000
#                         1954         Hydroxyterbuthylazine          0.130000
# 10915X0171/F      2011  1212         2,4-MCPA                       0.171000
# 10915X0315/F4     2007  1109         Atrazine déisopropyl           0.120000
# 10961X0030/GRABAS 2011  1529         Bitertanol                     0.125000
#                         1694         Tébuconazole                   0.210000
#                         1762         Penconazole                    0.111250
#                         1906         Fenbuconazole                  0.181250
# 10971X0058/F2     2009  2011         2,6-dichlorobenzamide          0.130000
# 10971X0200/MACHER 2008  1907         AMPA                           0.162500
# 11013X0002/F      2007  1263         Simazine                       0.166667
#
#                                                                     NBQUANTIF  \
# CD_STATION        ANNEE CD_PARAMETRE LB_PARAMETRE
# 00061X0120/F10    2009  1113         Bentazone                              1
# 00066X0042/SO     2007  1108         Atrazine déséthyl                      2
#                   2008  1108         Atrazine déséthyl                      2
#                   2009  1108         Atrazine déséthyl                      2
#                   2010  1108         Atrazine déséthyl                      2
#                   2011  1108         Atrazine déséthyl                      2
# 00075X0158/F15    2008  1506         Glyphosate                             1
#                   2009  1506         Glyphosate                             1
# 00108X0004/GC1    2007  1108         Atrazine déséthyl                      1
#                   2008  1108         Atrazine déséthyl                      1
#                   2009  1108         Atrazine déséthyl                      1
# 00108X0005/GC1    2007  1108         Atrazine déséthyl                      4
#                   2009  1108         Atrazine déséthyl                      2
# 00111X0244/GC1    2007  1108         Atrazine déséthyl                      2
#                   2009  1108         Atrazine déséthyl                      1
# 00113X0115/P2     2012  1108         Atrazine déséthyl                      1
# 00115X0004/P1     2007  1108         Atrazine déséthyl                      1
#                   2008  1108         Atrazine déséthyl                      1
# 00115X0030/P1     2007  1108         Atrazine déséthyl                     13
#                   2008  1108         Atrazine déséthyl                      7
#                   2009  1108         Atrazine déséthyl                      2
#                   2010  1108         Atrazine déséthyl                      2
#                   2011  1108         Atrazine déséthyl                      2
# 00116X0001/P1     2007  1108         Atrazine déséthyl                      4
#                   2008  1108         Atrazine déséthyl                      2
#                   2009  1108         Atrazine déséthyl                      1
#                   2011  1108         Atrazine déséthyl                      2
# 00126X0128/SO     2009  1105         Aminotriazole                          1
#                         1506         Glyphosate                             1
#                         1907         AMPA                                   1
# ...                                                                       ...
# 10744X0001/F      2009  1113         Bentazone                              1
# 10747X0035/HY     2007  1129         Carbendazime                           1
# 10783X0006/FREDE  2009  1954         Hydroxyterbuthylazine                  1
# 10795X0001/S      2008  1830         Déisopropyl-déséthyl-atrazine          3
#                   2009  1830         Déisopropyl-déséthyl-atrazine          2
# 10883X0210/FAGE   2007  1177         Diuron                                 1
# 10902X0002/S      2008  1830         Déisopropyl-déséthyl-atrazine          3
#                   2009  1830         Déisopropyl-déséthyl-atrazine          3
#                   2010  1830         Déisopropyl-déséthyl-atrazine          4
#                   2012  1830         Déisopropyl-déséthyl-atrazine          4
# 10903X0026/PENE   2008  1830         Déisopropyl-déséthyl-atrazine          2
#                   2009  1830         Déisopropyl-déséthyl-atrazine          3
#                   2010  1830         Déisopropyl-déséthyl-atrazine          4
#                   2011  1830         Déisopropyl-déséthyl-atrazine          3
#                   2012  1830         Déisopropyl-déséthyl-atrazine          2
# 10905X0014/D      2007  1506         Glyphosate                             1
#                   2008  1831         Simazine-hydroxy                       1
# 10907X0070/F      2007  1109         Atrazine déisopropyl                   1
#                         2045         Terbuthylazine déséthyl                1
#                   2009  1831         Simazine-hydroxy                       1
#                         1954         Hydroxyterbuthylazine                  1
# 10915X0171/F      2011  1212         2,4-MCPA                               1
# 10915X0315/F4     2007  1109         Atrazine déisopropyl                   1
# 10961X0030/GRABAS 2011  1529         Bitertanol                             1
#                         1694         Tébuconazole                           1
#                         1762         Penconazole                            1
#                         1906         Fenbuconazole                          1
# 10971X0058/F2     2009  2011         2,6-dichlorobenzamide                  1
# 10971X0200/MACHER 2008  1907         AMPA                                   1
# 11013X0002/F      2007  1263         Simazine                               6
#
#                                                                     NORME_DCE
# CD_STATION        ANNEE CD_PARAMETRE LB_PARAMETRE
# 00061X0120/F10    2009  1113         Bentazone                            0.1
# 00066X0042/SO     2007  1108         Atrazine déséthyl                    0.1
#                   2008  1108         Atrazine déséthyl                    0.1
#                   2009  1108         Atrazine déséthyl                    0.1
#                   2010  1108         Atrazine déséthyl                    0.1
#                   2011  1108         Atrazine déséthyl                    0.1
# 00075X0158/F15    2008  1506         Glyphosate                           0.1
#                   2009  1506         Glyphosate                           0.1
# 00108X0004/GC1    2007  1108         Atrazine déséthyl                    0.1
#                   2008  1108         Atrazine déséthyl                    0.1
#                   2009  1108         Atrazine déséthyl                    0.1
# 00108X0005/GC1    2007  1108         Atrazine déséthyl                    0.1
#                   2009  1108         Atrazine déséthyl                    0.1
# 00111X0244/GC1    2007  1108         Atrazine déséthyl                    0.1
#                   2009  1108         Atrazine déséthyl                    0.1
# 00113X0115/P2     2012  1108         Atrazine déséthyl                    0.1
# 00115X0004/P1     2007  1108         Atrazine déséthyl                    0.1
#                   2008  1108         Atrazine déséthyl                    0.1
# 00115X0030/P1     2007  1108         Atrazine déséthyl                    0.1
#                   2008  1108         Atrazine déséthyl                    0.1
#                   2009  1108         Atrazine déséthyl                    0.1
#                   2010  1108         Atrazine déséthyl                    0.1
#                   2011  1108         Atrazine déséthyl                    0.1
# 00116X0001/P1     2007  1108         Atrazine déséthyl                    0.1
#                   2008  1108         Atrazine déséthyl                    0.1
#                   2009  1108         Atrazine déséthyl                    0.1
#                   2011  1108         Atrazine déséthyl                    0.1
# 00126X0128/SO     2009  1105         Aminotriazole                        0.1
#                         1506         Glyphosate                           0.1
#                         1907         AMPA                                 0.1
# ...                                                                       ...
# 10744X0001/F      2009  1113         Bentazone                            0.1
# 10747X0035/HY     2007  1129         Carbendazime                         0.1
# 10783X0006/FREDE  2009  1954         Hydroxyterbuthylazine                0.1
# 10795X0001/S      2008  1830         Déisopropyl-déséthyl-atrazine        0.1
#                   2009  1830         Déisopropyl-déséthyl-atrazine        0.1
# 10883X0210/FAGE   2007  1177         Diuron                               0.1
# 10902X0002/S      2008  1830         Déisopropyl-déséthyl-atrazine        0.1
#                   2009  1830         Déisopropyl-déséthyl-atrazine        0.1
#                   2010  1830         Déisopropyl-déséthyl-atrazine        0.1
#                   2012  1830         Déisopropyl-déséthyl-atrazine        0.1
# 10903X0026/PENE   2008  1830         Déisopropyl-déséthyl-atrazine        0.1
#                   2009  1830         Déisopropyl-déséthyl-atrazine        0.1
#                   2010  1830         Déisopropyl-déséthyl-atrazine        0.1
#                   2011  1830         Déisopropyl-déséthyl-atrazine        0.1
#                   2012  1830         Déisopropyl-déséthyl-atrazine        0.1
# 10905X0014/D      2007  1506         Glyphosate                           0.1
#                   2008  1831         Simazine-hydroxy                     0.1
# 10907X0070/F      2007  1109         Atrazine déisopropyl                 0.1
#                         2045         Terbuthylazine déséthyl              0.1
#                   2009  1831         Simazine-hydroxy                     0.1
#                         1954         Hydroxyterbuthylazine                0.1
# 10915X0171/F      2011  1212         2,4-MCPA                             0.1
# 10915X0315/F4     2007  1109         Atrazine déisopropyl                 0.1
# 10961X0030/GRABAS 2011  1529         Bitertanol                           0.1
#                         1694         Tébuconazole                         0.1
#                         1762         Penconazole                          0.1
#                         1906         Fenbuconazole                        0.1
# 10971X0058/F2     2009  2011         2,6-dichlorobenzamide                0.1
# 10971X0200/MACHER 2008  1907         AMPA                                 0.1
# 11013X0002/F      2007  1263         Simazine                             0.1
#
# [4898 rows x 4 columns]

# %%
### -- MERGE DATAS -- ####################################

# %%
#df_stations_MCT_MA = pd.concat( [df_stations_MCT, df_MA] )
#df_stations_MCT_MA.head()


#print df_stations_MA_MCT.columns


# pivot tables
#df_mct_2008.T

# %%
### -- analysis --
## selections : http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-label
### TO DO

# %%
### -- exports --

### export functions

# %%
### return json
json_stations = df_stations.head(2).to_json(orient="index")
### pretty prints
parsed = json.loads(json_stations)
print json.dumps(parsed, indent=2, sort_keys=True)
# Out:
# {
#   "06521X0019/SCE": {
#     "ALTITUDE": 459.0,
#     "CD_ME_niv1_surf": "DG140",
#     "CD_ME_v2": null,
#     "COORD_WSG84": [
#       5.4528616689,
#       46.2707399979
#     ],
#     "LAT_WSG84": 5.4528616689,
#     "LONG_WSG84": 46.2707399979,
#     "NOM_COM": "CORVEISSIAT",
#     "NUM_COM": "01125",
#     "NUM_DEP": "01",
#     "PROFONDEUR_MAXI_POINT": null,
#     "Unit\u00e9_coord_fictifs": "01125_ _FRDG140",
#     "X_FICT_L93": 888869.8607,
#     "Y_FICT_L93": 6577473.549,
#     "codagence": "AERM&C",
#     "fi_ma_2007": "oui",
#     "fi_ma_2008": "oui",
#     "fi_ma_2009": "oui",
#     "fi_ma_2010": null,
#     "fi_ma_2011": null,
#     "fi_ma_2012": null,
#     "fi_ma_2013": null,
#     "fi_ma_2014": null,
#     "reseau2009": "Hors RCS et RCO",
#     "reseau2010": "horsRCSRCODRIRE",
#     "reseau2011": null,
#     "reseau2012": null,
#     "reseau2013": null,
#     "reseau2014": null
#   },
#   "07015X0009/F": {
#     "ALTITUDE": 229.0,
#     "CD_ME_niv1_surf": "DG330",
#     "CD_ME_v2": "DG330",
#     "COORD_WSG84": [
#       5.7818808671,
#       45.7930456698
#     ],
#     "LAT_WSG84": 5.7818808671,
#     "LONG_WSG84": 45.7930456698,
#     "NOM_COM": "CRESSIN-ROCHEFORT",
#     "NUM_COM": "01133",
#     "NUM_DEP": "01",
#     "PROFONDEUR_MAXI_POINT": 15.2,
#     "Unit\u00e9_coord_fictifs": "01133_FRDG511_FRDG330",
#     "X_FICT_L93": 916062.9395,
#     "Y_FICT_L93": 6525297.883,
#     "codagence": "AERM&C",
#     "fi_ma_2007": "oui",
#     "fi_ma_2008": null,
#     "fi_ma_2009": null,
#     "fi_ma_2010": null,
#     "fi_ma_2011": null,
#     "fi_ma_2012": null,
#     "fi_ma_2013": null,
#     "fi_ma_2014": null,
#     "reseau2009": "Hors RCS et RCO",
#     "reseau2010": null,
#     "reseau2011": null,
#     "reseau2012": null,
#     "reseau2013": null,
#     "reseau2014": null
#   }
# }
